# %%
import pandas as pd

# %%
#FROM NUMPY LISTS

# %%
data = [
["Alice", 25],
["Bob", 30],
["Charlie", 35]
]

# %%
d = pd.DataFrame(data, columns= ["Name", "Age"])

# %%
print(d)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
#FROM NUMPY ARRAYS

# %%
import numpy as np

# %%
a= np.array([[1,2], [3,4]])

# %%
dz = pd.DataFrame(a, columns= ["A", "B"])

# %%
print(dz)
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
#READING FILES IN PANDAS

# %%
r = pd.read_excel("Sample.xlsx")

# %%
print(r)
# Out:
#       Name  Age       City  Score   Department
# 0    Alice   25      Delhi     88  Engineering
# 1      Bob   30     Mumbai     92    Marketing
# 2  Charlie   35  Bangalore     85      Finance
# 3    David   28  Hyderabad     90           HR
# 4      Eva   22       Pune     95  Engineering
# 5    Frank   40    Chennai     78   Operations
# 6    Grace   27    Kolkata     89       Design
# 7   Hassan   33  Ahmedabad     91        Sales
# 8     Isha   29     Jaipur     87      Support
# 9     Jack   31    Lucknow     93  Engineering

# %%
rs=pd.read_csv("Sample.csv")

# %%
print(rs)
# Out:
#       Name  Age       City  Score   Department
# 0    Alice   25      Delhi     88  Engineering
# 1      Bob   30     Mumbai     92    Marketing
# 2  Charlie   35  Bangalore     85      Finance
# 3    David   28  Hyderabad     90           HR
# 4      Eva   22       Pune     95  Engineering
# 5    Frank   40    Chennai     78   Operations
# 6    Grace   27    Kolkata     89       Design
# 7   Hassan   33  Ahmedabad     91        Sales
# 8     Isha   29     Jaipur     87      Support
# 9     Jack   31    Lucknow     93  Engineering

# %%
df = pd.read_json("Sample.json")

# %%
print(df)
# Out:
#        Name  Age       City  Score   Department
# 0     Alice   25      Delhi     88  Engineering
# 1       Bob   30     Mumbai     92    Marketing
# 2   Charlie   35  Bangalore     85      Finance
# 3     David   28  Hyderabad     90           HR
# 4       Eva   22       Pune     95  Engineering
# ..      ...  ...        ...    ...          ...
# 85     Ajay   38    Chennai     81   Operations
# 86    Seema   26    Kolkata     94           HR
# 87   Tarika   33  Ahmedabad     86       Design
# 88   Manish   40     Jaipur     78      Finance
# 89     Renu   29    Lucknow     93      Support
#
# [90 rows x 5 columns]

# %%
df.head()
# Out:
#       Name  Age       City  Score   Department
# 0    Alice   25      Delhi     88  Engineering
# 1      Bob   30     Mumbai     92    Marketing
# 2  Charlie   35  Bangalore     85      Finance
# 3    David   28  Hyderabad     90           HR
# 4      Eva   22       Pune     95  Engineering

# %%
df.tail()
# Out:
#       Name  Age       City  Score  Department
# 85    Ajay   38    Chennai     81  Operations
# 86   Seema   26    Kolkata     94          HR
# 87  Tarika   33  Ahmedabad     86      Design
# 88  Manish   40     Jaipur     78     Finance
# 89    Renu   29    Lucknow     93     Support

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        90 non-null     object
#  1   Age         90 non-null     int64
#  2   City        90 non-null     object
#  3   Score       90 non-null     int64
#  4   Department  90 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 3.6+ KB

# %%
df.describe()
# Out:
#              Age      Score
# count  90.000000  90.000000
# mean   31.122222  87.766667
# std     5.325005   5.227520
# min    22.000000  77.000000
# 25%    27.000000  84.000000
# 50%    30.500000  88.500000
# 75%    35.000000  92.000000
# max    41.000000  97.000000

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Score', 'Department'], dtype='object')

# %%
df.shape
# Out:
# (90, 5)
